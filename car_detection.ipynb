# %% [markdown]
# <a href="https://colab.research.google.com/github/zeyzeppp/za/blob/main/car_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#yolov8 indir

# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.219 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.9/78.2 GB disk)

# %%
# drive'a baglan

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# calisma dizinini duzenlenir

import os
COLAB_PATH = "/content/drive/MyDrive"
os.chdir(COLAB_PATH)

# %%
#yolov8 klonlama

# !git clone https://github.com/ultralytics/ultralytics
# Out:
# fatal: destination path 'ultralytics' already exists and is not an empty directory.

# %%
# klonlanan dosyaya gitme
# %cd ultralytics

# kontrol etme
# !pwd
# Out:
# /content/drive/MyDrive/ultralytics/ultralytics
# /content/drive/MyDrive/ultralytics/ultralytics

# %%
# dosyalari listeleme
# !ls
# Out:
# assets	cfg  data  engine  hub	__init__.py  models  nn  __pycache__  trackers	utils

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/drive/MyDrive/yolov8/data/data.yaml epochs=50 imgsz=640 batch=8 project=/content/drive/MyDrive/yolov8/training_results name=car
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 98.0MB/s]
# Ultralytics YOLOv8.0.219 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/yolov8/training_results/car12/weights/best.pt conf=0.55 source=/content/drive/MyDrive/yolov8/data/test/images/b.jpg
# Out:
# Ultralytics YOLOv8.0.219 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/drive/MyDrive/yolov8/data/test/images/b.jpg: 640x640 1 araba, 7.4ms
# Speed: 2.2ms preprocess, 7.4ms inference, 88.7ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/yolov8/training_results/car12/weights/best.pt conf=0.55 source=/content/drive/MyDrive/yolov8/data/test/images/b.jpg
# Out:
# Ultralytics YOLOv8.0.219 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/drive/MyDrive/yolov8/data/test/images/b.jpg: 640x640 1 araba, 9.5ms
# Speed: 3.2ms preprocess, 9.5ms inference, 275.5ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cd runs/detect/predict
# Out:
# [Errno 2] No such file or directory: 'runs/detect/predict'
# /content/drive/MyDrive/ultralytics/ultralytics

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/yolov8/training_results/car12/weights/best.pt conf=0.50 source=/content/drive/MyDrive/yolov8/data/test/videos/highwayCar.mp4
# Out:
# Ultralytics YOLOv8.0.219 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (1/562) /content/drive/MyDrive/yolov8/data/test/videos/highwayCar.mp4: 384x640 15 arabas, 97.3ms
# video 1/1 (2/562) /content/drive/MyDrive/yolov8/data/test/videos/highwayCar.mp4: 384x640 13 arabas, 7.4ms
# video 1/1 (3/562) /content/drive/MyDrive/yolov8/data/test/videos/highwayCar.mp4: 384x640 13 arabas, 6.3ms
# video 1/1 (4/562) /content/drive/MyDrive/yolov8/data/test/videos/highwayCar.mp4: 384x640 13 arabas, 6.2ms
# video 1/1 (5/562) /content/drive/MyDrive/yolov8/data/test/videos/highwayCar.mp4: 384x640 13 arabas, 7.4ms
# video 1/1 (6/562) /content/drive/MyDrive/yolov8/data/test/videos/highwayCar.mp4: 384x640 12 arabas, 6.3ms
# video 1/1 (7/562) /content/drive/MyDrive/yolov8/data/test/videos/highwayCar.mp4: 384x640 14 arabas, 6.2ms
# ...

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/yolov8/training_results/car12/weights/best.pt conf=0.55 source=/content/drive/MyDrive/yolov8/data/test/demo_cars/images/download_1.jpg
# Out:
# Ultralytics YOLOv8.0.220 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/drive/MyDrive/yolov8/data/test/demo_cars/images/download_1.jpg: 352x640 5 arabas, 193.6ms
# Speed: 6.2ms preprocess, 193.6ms inference, 145.8ms postprocess per image at shape (1, 3, 352, 640)
# Results saved to /content/drive/MyDrive/ultralytics/runs/detect/predict6
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# ciktiyi gorsellestirme fonksiyonu

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def showImage(path):

  img = mpimg.imread(path)
  plt.figure(figsize = (10, 10))
  plt.imshow(img)
  plt.show()

# %%
showImage("/content/drive/MyDrive/ultralytics/runs/detect/predict6/download_1.jpg")

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/yolov8/training_results/car12/weights/best.pt conf=0.50 source=/content/drive/MyDrive/yolov8/data/test/demo_cars/videos/carHighway.mp4
# Out:
# Ultralytics YOLOv8.0.220 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (1/182) /content/drive/MyDrive/yolov8/data/test/demo_cars/videos/carHighway.mp4: 384x640 4 arabas, 107.3ms
# video 1/1 (2/182) /content/drive/MyDrive/yolov8/data/test/demo_cars/videos/carHighway.mp4: 384x640 5 arabas, 6.5ms
# video 1/1 (3/182) /content/drive/MyDrive/yolov8/data/test/demo_cars/videos/carHighway.mp4: 384x640 4 arabas, 7.4ms
# video 1/1 (4/182) /content/drive/MyDrive/yolov8/data/test/demo_cars/videos/carHighway.mp4: 384x640 4 arabas, 6.4ms
# video 1/1 (5/182) /content/drive/MyDrive/yolov8/data/test/demo_cars/videos/carHighway.mp4: 384x640 5 arabas, 6.0ms
# video 1/1 (6/182) /content/drive/MyDrive/yolov8/data/test/demo_cars/videos/carHighway.mp4: 384x640 5 arabas, 6.5ms
# video 1/1 (7/182) /content/drive/MyDrive/yolov8/data/test/demo_cars/videos/carHighway.mp4: 384x640 6 arabas, 7.1ms
# ...
