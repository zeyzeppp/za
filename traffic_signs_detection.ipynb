# %% [markdown]
# <a href="https://colab.research.google.com/github/zeyzeppp/za/blob/main/traffic_signs_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#yolov8 indir

# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.225 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.9/78.2 GB disk)

# %%
# drive'a baglan

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# calisma dizinini duzenlenir

import os
COLAB_PATH = "/content/drive/MyDrive"
os.chdir(COLAB_PATH)

# %%
#yolov8 klonlama

# !git clone https://github.com/ultralytics/ultralytics
# Out:
# fatal: destination path 'ultralytics' already exists and is not an empty directory.

# %%
# klonlanan dosyaya gitme
# %cd ultralytics

# kontrol etme
# !pwd
# Out:
# /content/drive/MyDrive/ultralytics
# /content/drive/MyDrive/ultralytics

# %%
# dosyalari listeleme
# !ls
# Out:
# CITATION.cff	 docker  examples  MANIFEST.in	README.zh-CN.md   runs	     setup.py  ultralytics
# CONTRIBUTING.md  docs	 LICENSE   README.md	requirements.txt  setup.cfg  tests     yolov8n.pt

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/drive/MyDrive/yolov8/data_signs/data_signs.yaml epochs=150 imgsz=640 batch=8 project=/content/drive/MyDrive/yolov8/trafficSigns_result name=ts
# Out:
# Ultralytics YOLOv8.0.225 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/yolov8/trafficSigns_result/ts3/weights/best.pt conf=0.25 source=/content/drive/MyDrive/yolov8/data_signs/test/images/as.jpg
# Out:
# Ultralytics YOLOv8.0.225 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3007208 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/drive/MyDrive/yolov8/data_signs/test/images/as.jpg: 640x640 1 turn_right_ahead, 9.8ms
# Speed: 2.5ms preprocess, 9.8ms inference, 113.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict13
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# ciktiyi gorsellestirme fonksiyonu

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def showImage(path):

  img = mpimg.imread(path)
  plt.figure(figsize = (10, 10))
  plt.imshow(img)
  plt.show()

# %%
showImage("/content/drive/MyDrive/ultralytics/runs/detect/predict13/as.jpg")

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/yolov8/trafficSigns_result/ts3/weights/best.pt conf=0.25 source=/content/drive/MyDrive/yolov8/data_signs/test/images/d.jpg
# Out:
# Ultralytics YOLOv8.0.225 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3007208 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/drive/MyDrive/yolov8/data_signs/test/images/d.jpg: 640x640 1 max_speed_50km-h, 9.3ms
# Speed: 2.5ms preprocess, 9.3ms inference, 104.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict14
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
showImage("/content/drive/MyDrive/ultralytics/runs/detect/predict14/d.jpg")

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/yolov8/trafficSigns_result/ts3/weights/best.pt conf=0.25 source=/content/drive/MyDrive/yolov8/data_signs/dr/download.png
# Out:
# Ultralytics YOLOv8.0.225 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3007208 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/drive/MyDrive/yolov8/data_signs/dr/download.png: 608x640 1 no_entry, 58.6ms
# Speed: 3.8ms preprocess, 58.6ms inference, 83.4ms postprocess per image at shape (1, 3, 608, 640)
# Results saved to runs/detect/predict16
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
showImage("/content/drive/MyDrive/ultralytics/runs/detect/predict16/download.png")
